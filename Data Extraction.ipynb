# %% [markdown]
# ## Building an Expected Goals (xG) Model Using Statsbomb Free Data
# A data science project using [StatsBomb](https://statsbomb.com/) event data to build an expected goals model. This notebook is the first in a series of project notebooks in which I extract shots data from the Statsbomb API.
#
# #### By Dahbi El Mehdi

# %% [markdown]
# ___
#
# <a id='sectioncontents'></a>
#
# ## <a id='notebook_contents'>Notebook Contents</a>
# 1.    [Notebook Dependencies](#section1)<br>
# 2.    [Notebook Brief](#section2)<br>
# 3.    [Data Collection](#section3)<br>
# 4.    [Extraction Outcome](#section4)<br>

# %% [markdown]
# ___
#
# <a id='section1'></a>
#
# ## <a id='#section1'>1. Notebook Dependencies</a>
#
# This notebook was written using [Python 3](https://docs.python.org/3.7/) and requires the following libraries:
# *    [`Jupyter notebooks`](https://jupyter.org/) for this notebook environment with which this project is presented;
# *    [`pandas`](http://pandas.pydata.org/) for data manipulation.
# *    [`statsbombpy`](https://github.com/statsbomb/statsbombpy) a python package to easily stream StatsBomb data into Python.

# %%
# Install statsbombpy package to extract event data
# !pip install statsbombpy
from statsbombpy import sb

# warnings to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# data manipulation
import pandas as pd
# Out:
# Requirement already satisfied: statsbombpy in c:\users\pc\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: requests-cache in c:\users\pc\anaconda3\lib\site-packages (from statsbombpy) (0.9.8)
# Requirement already satisfied: inflect in c:\users\pc\anaconda3\lib\site-packages (from statsbombpy) (6.0.2)
# Requirement already satisfied: requests in c:\users\pc\anaconda3\lib\site-packages (from statsbombpy) (2.27.1)
# Requirement already satisfied: pandas in c:\users\pc\anaconda3\lib\site-packages (from statsbombpy) (1.4.2)
# Requirement already satisfied: nose2 in c:\users\pc\anaconda3\lib\site-packages (from statsbombpy) (0.12.0)
# Requirement already satisfied: joblib in c:\users\pc\anaconda3\lib\site-packages (from statsbombpy) (1.1.0)
# Requirement already satisfied: pydantic>=1.9.1 in c:\users\pc\anaconda3\lib\site-packages (from inflect->statsbombpy) (1.10.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\pc\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->statsbombpy) (4.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\anaconda3\lib\site-packages (from pandas->statsbombpy) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\pc\anaconda3\lib\site-packages (from pandas->statsbombpy) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pc\anaconda3\lib\site-packages (from pandas->statsbombpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->statsbombpy) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\anaconda3\lib\site-packages (from requests->statsbombpy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\anaconda3\lib\site-packages (from requests->statsbombpy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pc\anaconda3\lib\site-packages (from requests->statsbombpy) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from requests->statsbombpy) (2.0.4)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\pc\anaconda3\lib\site-packages (from requests-cache->statsbombpy) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in c:\users\pc\anaconda3\lib\site-packages (from requests-cache->statsbombpy) (21.4.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\pc\anaconda3\lib\site-packages (from requests-cache->statsbombpy) (22.2.0)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\pc\anaconda3\lib\site-packages (from requests-cache->statsbombpy) (1.4.3)
# Requirement already satisfied: exceptiongroup in c:\users\pc\anaconda3\lib\site-packages (from cattrs>=22.2->requests-cache->statsbombpy) (1.1.0)

# %% [markdown]
# <a id='section2'></a>
#
# ## <a id='#section2'>2. Notebook Brief</a>
# This Jupyter notebook is part of a series of notebooks, to extract, save, clean, prepare a dataset, culminating with basic modeling, to **Build an Expected Goals model**.
#
# To do so, we'll follow these steps:
# <ul>
#     <li>Extracting competitions ids</li>
#     <li>Make a dataframe with all of the selected competitions' matches.</li>
#     <li>Using match ids to retrieve all shots</li>
#     <li>Save the dataframe as a parquet file.</li>
# </ul>

# %% [markdown]
# ___
#
# <a id='section3'></a>
#
# ## <a id='#section3'>3. Data Extraction</a>

# %%
# Create a dataframe from ststsbomby competitions 
competitions_df= sb. competitions()

# Get the available competitions
print('Available compeititons:', competitions_df['competition_name'].unique())
# Out:
# Available compeititons: ['Champions League' "FA Women's Super League" 'FIFA World Cup'
#  'Indian Super league' 'La Liga' 'NWSL' 'Premier League' 'UEFA Euro'
#  "UEFA Women's Euro" "Women's World Cup"]

# %%
# We're interested in keepoing as much dataas we can, so we'll extract shots events from all matches
# of the different men competitions

# competitions ids
comps_ids= competitions_df['competition_id'].unique()

# Seasons ids
seasons_ids= competitions_df['season_id'].unique()

# %%
print(comps_ids)
# Out:
# [  16   37   43 1238   11   49    2   55   53   72]

# %%
# Competitions names, id, and seasons to extract

print("Competitions names:",
      competitions_df['competition_name'].unique(),
      '\n',
      "Competitions ids:",
      comps_ids,
      '\n',
      "Seasons ids:",
      seasons_ids)
# Out:
# Competitions names: ['Champions League' "FA Women's Super League" 'FIFA World Cup'
#  'Indian Super league' 'La Liga' 'NWSL' 'Premier League' 'UEFA Euro'
#  "UEFA Women's Euro" "Women's World Cup"]
#  Competitions ids: [  16   37   43 1238   11   49    2   55   53   72]
#  Seasons ids: [  4   1   2  27  26  25  24  23  22  21  41  39  37  44  76  90  42 106
#    3 108  40  38  43  30]

# %%
comps_ids= competitions_df['competition_id']
comps_seasons= competitions_df['season_id']

matches_dfs = sb.matches(competition_id = 43, season_id = 106)

for id, season in zip(comps_ids, comps_seasons):
    try:
        matches_df = sb.matches(competition_id = id, season_id = season)
    except: 
        pass
    matches_dfs = matches_dfs.append(matches_df, ignore_index = 1)

# %%
matches_dfs= matches_dfs.drop_duplicates()
matches_dfs.head()
# Out:
#    match_id  match_date      kick_off                     competition season  \
# 0   3869254  2022-12-06  21:00:00.000  International - FIFA World Cup   2022
# 1   3869118  2022-12-04  21:00:00.000  International - FIFA World Cup   2022
# 2   3869486  2022-12-10  17:00:00.000  International - FIFA World Cup   2022
# 3   3869685  2022-12-18  17:00:00.000  International - FIFA World Cup   2022
# 4   3869684  2022-12-17  17:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  ...  \
# 0   Portugal  Switzerland           6           1    available  ...
# 1    England      Senegal           3           0    available  ...
# 2    Morocco     Portugal           1           0    available  ...
# 3  Argentina       France           3           3    available  ...
# 4    Croatia      Morocco           2           1    available  ...
#
#              last_updated_360 match_week competition_stage  \
# 0  2023-01-14T15:08:46.172894          4       Round of 16
# 1  2022-12-13T21:39:52.223504          4       Round of 16
# 2  2023-01-04T12:36:10.102347          5    Quarter-finals
# 3  2022-12-21T16:02:21.075183          7             Final
# 4  2022-12-18T21:30:47.341680          7   3rd Place Final
#
#                                 stadium                        referee  \
# 0                        Lusail Stadium  César Arturo Ramos Palazuelos
# 1                       Al Bayt Stadium   Ivan Arcides Barton Cisneros
# 2                    Al Thumama Stadium         Facundo Tello Figueroa
# 3                        Lusail Stadium               Szymon Marciniak
# 4  Sheikh Khalifa International Stadium  Abdulrahman Ibrahim Al Jassim
#
#                                home_managers  \
# 0  Fernando Manuel Fernandes da Costa Santos
# 1                           Gareth Southgate
# 2                            Hoalid Regragui
# 3                   Lionel Sebastián Scaloni
# 4                               Zlatko Dalić
#
#                                away_managers data_version  \
# 0                                Murat Yakin        1.1.0
# 1                                Aliou Cissé        1.1.0
# 2  Fernando Manuel Fernandes da Costa Santos        1.1.0
# 3                           Didier Deschamps        1.1.0
# 4                            Hoalid Regragui        1.1.0
#
#   shot_fidelity_version xy_fidelity_version
# 0                     2                   2
# 1                     2                   2
# 2                     2                   2
# 3                     2                   2
# 4                     2                   2
#
# [5 rows x 22 columns]

# %%
matches_dfs
# Out:
#       match_id  match_date      kick_off                        competition  \
# 0      3869254  2022-12-06  21:00:00.000     International - FIFA World Cup
# 1      3869118  2022-12-04  21:00:00.000     International - FIFA World Cup
# 2      3869486  2022-12-10  17:00:00.000     International - FIFA World Cup
# 3      3869685  2022-12-18  17:00:00.000     International - FIFA World Cup
# 4      3869684  2022-12-17  17:00:00.000     International - FIFA World Cup
# ...        ...         ...           ...                                ...
# 1367     69199  2019-06-27  21:00:00.000  International - Women's World Cup
# 1368     69258  2019-07-02  21:00:00.000  International - Women's World Cup
# 1369     69284  2019-07-03  21:00:00.000  International - Women's World Cup
# 1370     69205  2019-06-29  15:00:00.000  International - Women's World Cup
# 1371     69161  2019-06-24  18:00:00.000  International - Women's World Cup
#
#      season            home_team              away_team  home_score  \
# 0      2022             Portugal            Switzerland           6
# 1      2022              England                Senegal           3
# 2      2022              Morocco               Portugal           1
# 3      2022            Argentina                 France           3
# 4      2022              Croatia                Morocco           2
# ...     ...                  ...                    ...         ...
# 1367   2019       Norway Women's        England Women's           0
# 1368   2019      England Women's  United States Women's           1
# 1369   2019  Netherlands Women's         Sweden Women's           1
# 1370   2019        Italy Women's    Netherlands Women's           0
# 1371   2019        Spain Women's  United States Women's           1
#
#       away_score match_status  ...            last_updated_360 match_week  \
# 0              1    available  ...  2023-01-14T15:08:46.172894          4
# 1              0    available  ...  2022-12-13T21:39:52.223504          4
# 2              0    available  ...  2023-01-04T12:36:10.102347          5
# 3              3    available  ...  2022-12-21T16:02:21.075183          7
# 4              1    available  ...  2022-12-18T21:30:47.341680          7
# ...          ...          ...  ...                         ...        ...
# 1367           3    available  ...     2021-06-13T16:17:31.694          5
# 1368           2    available  ...     2021-06-13T16:17:31.694          6
# 1369           0    available  ...     2021-06-13T16:17:31.694          6
# 1370           2    available  ...     2021-06-13T16:17:31.694          5
# 1371           2    available  ...     2021-06-13T16:17:31.694          4
#
#      competition_stage                               stadium  \
# 0          Round of 16                        Lusail Stadium
# 1          Round of 16                       Al Bayt Stadium
# 2       Quarter-finals                    Al Thumama Stadium
# 3                Final                        Lusail Stadium
# 4      3rd Place Final  Sheikh Khalifa International Stadium
# ...                ...                                   ...
# 1367    Regular Season                          Stade Océane
# 1368       Semi-finals                      Groupama Stadium
# 1369       Semi-finals                      Groupama Stadium
# 1370    Regular Season                      Stade du Hainaut
# 1371       Round of 16             Stade Auguste-Delaune II
#
#                             referee  \
# 0     César Arturo Ramos Palazuelos
# 1      Ivan Arcides Barton Cisneros
# 2            Facundo Tello Figueroa
# 3                  Szymon Marciniak
# 4     Abdulrahman Ibrahim Al Jassim
# ...                             ...
# 1367          Lucila Venegas Montes
# 1368                            NaN
# 1369          Marie-Soleil Beaudoin
# 1370              Claudia Umpiérrez
# 1371                Katalin Kulcsar
#
#                                   home_managers  \
# 0     Fernando Manuel Fernandes da Costa Santos
# 1                              Gareth Southgate
# 2                               Hoalid Regragui
# 3                      Lionel Sebastián Scaloni
# 4                                  Zlatko Dalić
# ...                                         ...
# 1367                             Martin Sjögren
# 1368                               Phil Neville
# 1369                   Sarina Glotzbach-Wiegman
# 1370                           Milena Bertolini
# 1371                                Jorge Vilda
#
#                                   away_managers data_version  \
# 0                                   Murat Yakin        1.1.0
# 1                                   Aliou Cissé        1.1.0
# 2     Fernando Manuel Fernandes da Costa Santos        1.1.0
# 3                              Didier Deschamps        1.1.0
# 4                               Hoalid Regragui        1.1.0
# ...                                         ...          ...
# 1367                               Phil Neville        1.1.0
# 1368                              Jillian Ellis        1.1.0
# 1369                          Peter Gerhardsson        1.1.0
# 1370                   Sarina Glotzbach-Wiegman        1.1.0
# 1371                              Jillian Ellis        1.1.0
#
#      shot_fidelity_version xy_fidelity_version
# 0                        2                   2
# 1                        2                   2
# 2                        2                   2
# 3                        2                   2
# 4                        2                   2
# ...                    ...                 ...
# 1367                     2                   2
# 1368                     2                   2
# 1369                     2                   2
# 1370                     2                   2
# 1371                     2                   2
#
# [1307 rows x 22 columns]

# %%
# Creating a list of matches ids
matches_ids= matches_dfs["match_id"]

all_events= sb.events(match_id=matches_ids[0], split=True, flatten_attrs=True)["shots"]

for id in matches_ids[1:]:
    all_events= all_events.append(sb.events(match_id=id, split=True, flatten_attrs=True)["shots"], ignore_index = 1)
    print('Shots scraped from match with id:'+ str(id))
# Out:
# Shots scraped from match with id:3869118
# Shots scraped from match with id:3869486
# Shots scraped from match with id:3869685
# Shots scraped from match with id:3869684
# Shots scraped from match with id:3869519
# Shots scraped from match with id:3869354
# Shots scraped from match with id:3869552
# Shots scraped from match with id:3869420
# Shots scraped from match with id:3869321
# Shots scraped from match with id:3869220
# Shots scraped from match with id:3869219
# Shots scraped from match with id:3869253
# Shots scraped from match with id:3869151
# Shots scraped from match with id:3869152
# Shots scraped from match with id:3869117
# Shots scraped from match with id:3857256
# Shots scraped from match with id:3857270
# Shots scraped from match with id:3857269
# Shots scraped from match with id:3857263
# Shots scraped from match with id:3857259
# Shots scraped from match with id:3857295
# Shots scraped from match with id:3857266
# Shots scraped from match with id:3857283
# Shots scraped from match with id:3857284
# Shots scraped from match with id:3857282
# Shots scraped from match with id:3857286
# Shots scraped from match with id:3857301
# Shots scraped from match with id:3857300
# Shots scraped from match with id:3857299
# Shots scraped from match with id:3857298
# Shots scraped from match with id:3857297
# Shots scraped from match with id:3857296
# Shots scraped from match with id:3857294
# Shots scraped from match with id:3857293
# Shots scraped from match with id:3857292
# Shots scraped from match with id:3857291
# Shots scraped from match with id:3857290
# Shots scraped from match with id:3857289
# Shots scraped from match with id:3857288
# Shots scraped from match with id:3857287
# Shots scraped from match with id:3857285
# Shots scraped from match with id:3857281
# Shots scraped from match with id:3857280
# Shots scraped from match with id:3857279
# Shots scraped from match with id:3857278
# Shots scraped from match with id:3857277
# Shots scraped from match with id:3857276
# Shots scraped from match with id:3857275
# Shots scraped from match with id:3857274
# Shots scraped from match with id:3857273
# Shots scraped from match with id:3857272
# Shots scraped from match with id:3857271
# Shots scraped from match with id:3857268
# Shots scraped from match with id:3857267
# Shots scraped from match with id:3857265
# Shots scraped from match with id:3857264
# Shots scraped from match with id:3857262
# Shots scraped from match with id:3857261
# Shots scraped from match with id:3857260
# Shots scraped from match with id:3857258
# Shots scraped from match with id:3857257
# Shots scraped from match with id:3857255
# Shots scraped from match with id:3857254
# Shots scraped from match with id:22912
# Shots scraped from match with id:18245
# Shots scraped from match with id:18244
# Shots scraped from match with id:18243
# Shots scraped from match with id:18242
# Shots scraped from match with id:18241
# Shots scraped from match with id:18240
# Shots scraped from match with id:18237
# Shots scraped from match with id:18236
# Shots scraped from match with id:18235
# Shots scraped from match with id:3750201
# Shots scraped from match with id:3750200
# Shots scraped from match with id:2302764
# Shots scraped from match with id:3752619
# Shots scraped from match with id:3775648
# Shots scraped from match with id:3775609
# Shots scraped from match with id:3775633
# Shots scraped from match with id:3775570
# Shots scraped from match with id:3775581
# Shots scraped from match with id:3775579
# Shots scraped from match with id:3775544
# Shots scraped from match with id:3775622
# Shots scraped from match with id:3775553
# Shots scraped from match with id:3775584
# Shots scraped from match with id:3775618
# Shots scraped from match with id:3775641
# Shots scraped from match with id:3775636
# Shots scraped from match with id:3775653
# Shots scraped from match with id:3775654
# Shots scraped from match with id:3775643
# Shots scraped from match with id:3764237
# Shots scraped from match with id:3775594
# Shots scraped from match with id:3775560
# Shots scraped from match with id:3775624
# Shots scraped from match with id:3764240
# Shots scraped from match with id:3764233
# Shots scraped from match with id:3775585
# Shots scraped from match with id:3775593
# Shots scraped from match with id:3775602
# Shots scraped from match with id:3775620
# Shots scraped from match with id:3764232
# Shots scraped from match with id:3775559
# Shots scraped from match with id:3775606
# Shots scraped from match with id:3775567
# Shots scraped from match with id:3775638
# Shots scraped from match with id:3775607
# Shots scraped from match with id:3764230
# Shots scraped from match with id:3764241
# Shots scraped from match with id:3764235
# Shots scraped from match with id:3764239
# Shots scraped from match with id:3764236
# Shots scraped from match with id:3764231
# Shots scraped from match with id:3764234
# Shots scraped from match with id:3775543
# Shots scraped from match with id:3775551
# Shots scraped from match with id:3775540
# Shots scraped from match with id:3775550
# Shots scraped from match with id:3775545
# Shots scraped from match with id:3775556
# Shots scraped from match with id:3775575
# Shots scraped from match with id:3775562
# Shots scraped from match with id:3775561
# Shots scraped from match with id:3775582
# Shots scraped from match with id:3775558
# Shots scraped from match with id:3775552
# Shots scraped from match with id:3775557
# Shots scraped from match with id:3775564
# Shots scraped from match with id:3775569
# Shots scraped from match with id:3775548
# Shots scraped from match with id:3775568
# Shots scraped from match with id:3775563
# Shots scraped from match with id:3775555
# Shots scraped from match with id:3775549
# Shots scraped from match with id:3775572
# Shots scraped from match with id:3775577
# Shots scraped from match with id:3775541
# Shots scraped from match with id:3775588
# Shots scraped from match with id:3775586
# Shots scraped from match with id:3775592
# Shots scraped from match with id:3775580
# Shots scraped from match with id:3775591
# Shots scraped from match with id:3775590
# Shots scraped from match with id:3775571
# Shots scraped from match with id:3775589
# Shots scraped from match with id:3775578
# Shots scraped from match with id:3775596
# Shots scraped from match with id:3775576
# Shots scraped from match with id:3775574
# Shots scraped from match with id:3775573
# Shots scraped from match with id:3775597
# Shots scraped from match with id:3775611
# Shots scraped from match with id:3775628
# Shots scraped from match with id:3775612
# Shots scraped from match with id:3775627
# Shots scraped from match with id:3775644
# Shots scraped from match with id:3775637
# Shots scraped from match with id:3775631
# Shots scraped from match with id:3775621
# Shots scraped from match with id:3775615
# Shots scraped from match with id:3775610
# Shots scraped from match with id:3775616
# Shots scraped from match with id:3775632
# Shots scraped from match with id:3775629
# Shots scraped from match with id:3775619
# Shots scraped from match with id:3775600
# Shots scraped from match with id:3775605
# Shots scraped from match with id:3775626
# Shots scraped from match with id:3775614
# Shots scraped from match with id:3775603
# Shots scraped from match with id:3775625
# Shots scraped from match with id:3775613
# Shots scraped from match with id:3775598
# Shots scraped from match with id:3775601
# Shots scraped from match with id:3775630
# Shots scraped from match with id:3775651
# Shots scraped from match with id:3775635
# Shots scraped from match with id:3775650
# Shots scraped from match with id:3775647
# Shots scraped from match with id:3775659
# Shots scraped from match with id:3775657
# Shots scraped from match with id:3775649
# Shots scraped from match with id:3775645
# Shots scraped from match with id:3775639
# Shots scraped from match with id:3775642
# Shots scraped from match with id:3775646
# Shots scraped from match with id:3775655
# Shots scraped from match with id:3775640
# Shots scraped from match with id:3775658
# Shots scraped from match with id:3775623
# Shots scraped from match with id:3775566
# Shots scraped from match with id:3775546
# Shots scraped from match with id:3775547
# Shots scraped from match with id:3775587
# Shots scraped from match with id:3775595
# Shots scraped from match with id:3775604
# Shots scraped from match with id:3775634
# Shots scraped from match with id:3775617
# Shots scraped from match with id:3775565
# Shots scraped from match with id:3775583
# Shots scraped from match with id:3775542
# Shots scraped from match with id:3775608
# Shots scraped from match with id:3775599
# Shots scraped from match with id:3775554
# Shots scraped from match with id:3775652
# Shots scraped from match with id:3764238
# Shots scraped from match with id:2275127
# Shots scraped from match with id:2275136
# Shots scraped from match with id:2275154
# Shots scraped from match with id:2275150
# Shots scraped from match with id:2275146
# Shots scraped from match with id:2275142
# Shots scraped from match with id:2275137
# Shots scraped from match with id:2275153
# Shots scraped from match with id:2275151
# Shots scraped from match with id:2275144
# Shots scraped from match with id:2275088
# Shots scraped from match with id:2275110
# Shots scraped from match with id:2275044
# Shots scraped from match with id:2275105
# Shots scraped from match with id:2275063
# Shots scraped from match with id:2275054
# Shots scraped from match with id:2275072
# Shots scraped from match with id:2275085
# Shots scraped from match with id:2275113
# Shots scraped from match with id:2275099
# Shots scraped from match with id:2275057
# Shots scraped from match with id:2275075
# Shots scraped from match with id:2275077
# Shots scraped from match with id:2275036
# Shots scraped from match with id:2275117
# Shots scraped from match with id:2275092
# Shots scraped from match with id:2275040
# Shots scraped from match with id:2275122
# Shots scraped from match with id:2275045
# Shots scraped from match with id:2275093
# Shots scraped from match with id:2275097
# Shots scraped from match with id:2275084
# Shots scraped from match with id:2275089
# Shots scraped from match with id:2275116
# Shots scraped from match with id:2275104
# Shots scraped from match with id:2275052
# Shots scraped from match with id:2275037
# Shots scraped from match with id:2275027
# Shots scraped from match with id:2275078
# Shots scraped from match with id:2275080
# Shots scraped from match with id:2275098
# Shots scraped from match with id:2275156
# Shots scraped from match with id:2275139
# Shots scraped from match with id:2275070
# Shots scraped from match with id:2275051
# Shots scraped from match with id:2275050
# Shots scraped from match with id:2275029
# Shots scraped from match with id:2275090
# Shots scraped from match with id:2275042
# Shots scraped from match with id:2275157
# Shots scraped from match with id:2275108
# Shots scraped from match with id:2275082
# Shots scraped from match with id:2275138
# Shots scraped from match with id:2275049
# Shots scraped from match with id:2275132
# Shots scraped from match with id:2275061
# Shots scraped from match with id:2275096
# Shots scraped from match with id:2275033
# Shots scraped from match with id:2275107
# Shots scraped from match with id:2275130
# Shots scraped from match with id:2275034
# Shots scraped from match with id:2275026
# Shots scraped from match with id:2275041
# Shots scraped from match with id:2275094
# Shots scraped from match with id:2275106
# Shots scraped from match with id:2275073
# Shots scraped from match with id:2275038
# Shots scraped from match with id:2275131
# Shots scraped from match with id:2275062
# Shots scraped from match with id:2275048
# Shots scraped from match with id:2275121
# Shots scraped from match with id:2275065
# Shots scraped from match with id:2275079
# Shots scraped from match with id:2275103
# Shots scraped from match with id:2275140
# Shots scraped from match with id:2275126
# Shots scraped from match with id:2275102
# Shots scraped from match with id:2275109
# Shots scraped from match with id:2275091
# Shots scraped from match with id:2275030
# Shots scraped from match with id:2275133
# Shots scraped from match with id:2275083
# Shots scraped from match with id:2275120
# Shots scraped from match with id:2275028
# Shots scraped from match with id:2275086
# Shots scraped from match with id:2275056
# Shots scraped from match with id:2275074
# Shots scraped from match with id:7298
# Shots scraped from match with id:19778
# Shots scraped from match with id:19771
# Shots scraped from match with id:19736
# Shots scraped from match with id:19745
# Shots scraped from match with id:19772
# Shots scraped from match with id:19730
# Shots scraped from match with id:19794
# Shots scraped from match with id:19820
# Shots scraped from match with id:19766
# Shots scraped from match with id:19734
# Shots scraped from match with id:19717
# Shots scraped from match with id:19718
# Shots scraped from match with id:19810
# Shots scraped from match with id:19743
# Shots scraped from match with id:19740
# Shots scraped from match with id:19716
# Shots scraped from match with id:19800
# Shots scraped from match with id:19739
# Shots scraped from match with id:19748
# Shots scraped from match with id:19822
# Shots scraped from match with id:19785
# Shots scraped from match with id:19749
# Shots scraped from match with id:19751
# Shots scraped from match with id:19764
# Shots scraped from match with id:19773
# Shots scraped from match with id:19783
# Shots scraped from match with id:19747
# Shots scraped from match with id:19769
# Shots scraped from match with id:19770
# Shots scraped from match with id:19757
# Shots scraped from match with id:19742
# Shots scraped from match with id:19777
# Shots scraped from match with id:19758
# Shots scraped from match with id:19802
# Shots scraped from match with id:19803
# Shots scraped from match with id:19746
# Shots scraped from match with id:19811
# Shots scraped from match with id:19805
# Shots scraped from match with id:19752
# Shots scraped from match with id:19775
# Shots scraped from match with id:19760
# Shots scraped from match with id:19787
# Shots scraped from match with id:19733
# Shots scraped from match with id:19765
# Shots scraped from match with id:19792
# Shots scraped from match with id:19732
# Shots scraped from match with id:19744
# Shots scraped from match with id:19799
# Shots scraped from match with id:19753
# Shots scraped from match with id:19735
# Shots scraped from match with id:19720
# Shots scraped from match with id:19719
# Shots scraped from match with id:19715
# Shots scraped from match with id:19723
# Shots scraped from match with id:19722
# Shots scraped from match with id:19727
# Shots scraped from match with id:19731
# Shots scraped from match with id:19714
# Shots scraped from match with id:19728
# Shots scraped from match with id:19726
# Shots scraped from match with id:19725
# Shots scraped from match with id:19738
# Shots scraped from match with id:19759
# Shots scraped from match with id:19750
# Shots scraped from match with id:19761
# Shots scraped from match with id:19762
# Shots scraped from match with id:19763
# Shots scraped from match with id:19768
# Shots scraped from match with id:19767
# Shots scraped from match with id:19776
# Shots scraped from match with id:19737
# Shots scraped from match with id:19790
# Shots scraped from match with id:19793
# Shots scraped from match with id:19789
# Shots scraped from match with id:19791
# Shots scraped from match with id:19795
# Shots scraped from match with id:19797
# Shots scraped from match with id:19780
# Shots scraped from match with id:19781
# Shots scraped from match with id:19779
# Shots scraped from match with id:19798
# Shots scraped from match with id:19782
# Shots scraped from match with id:19784
# Shots scraped from match with id:19786
# Shots scraped from match with id:19774
# Shots scraped from match with id:19755
# Shots scraped from match with id:19806
# Shots scraped from match with id:19807
# Shots scraped from match with id:19788
# Shots scraped from match with id:19808
# Shots scraped from match with id:19804
# Shots scraped from match with id:19813
# Shots scraped from match with id:19816
# Shots scraped from match with id:19809
# Shots scraped from match with id:19815
# Shots scraped from match with id:19817
# Shots scraped from match with id:19818
# Shots scraped from match with id:19819
# Shots scraped from match with id:19821
# Shots scraped from match with id:19801
# Shots scraped from match with id:19741
# Shots scraped from match with id:19756
# Shots scraped from match with id:19754
# Shots scraped from match with id:19724
# Shots scraped from match with id:19814
# Shots scraped from match with id:19729
# Shots scraped from match with id:19796
# Shots scraped from match with id:7548
# Shots scraped from match with id:7578
# Shots scraped from match with id:7553
# Shots scraped from match with id:7544
# Shots scraped from match with id:7536
# Shots scraped from match with id:7555
# Shots scraped from match with id:7546
# Shots scraped from match with id:7539
# Shots scraped from match with id:7538
# Shots scraped from match with id:7576
# Shots scraped from match with id:7565
# Shots scraped from match with id:7551
# Shots scraped from match with id:7550
# Shots scraped from match with id:7537
# Shots scraped from match with id:7580
# Shots scraped from match with id:8650
# Shots scraped from match with id:7581
# Shots scraped from match with id:7549
# Shots scraped from match with id:7529
# Shots scraped from match with id:7534
# Shots scraped from match with id:7562
# Shots scraped from match with id:7571
# Shots scraped from match with id:7569
# Shots scraped from match with id:7568
# Shots scraped from match with id:7530
# Shots scraped from match with id:7558
# Shots scraped from match with id:7583
# Shots scraped from match with id:7547
# Shots scraped from match with id:7535
# Shots scraped from match with id:7584
# Shots scraped from match with id:7545
# Shots scraped from match with id:8649
# Shots scraped from match with id:8658
# Shots scraped from match with id:7561
# Shots scraped from match with id:7531
# Shots scraped from match with id:7582
# Shots scraped from match with id:7552
# Shots scraped from match with id:7532
# Shots scraped from match with id:7560
# Shots scraped from match with id:7533
# Shots scraped from match with id:7564
# Shots scraped from match with id:7579
# Shots scraped from match with id:7572
# Shots scraped from match with id:7577
# Shots scraped from match with id:7543
# Shots scraped from match with id:7525
# Shots scraped from match with id:7542
# Shots scraped from match with id:7566
# Shots scraped from match with id:7557
# Shots scraped from match with id:7554
# Shots scraped from match with id:7570
# Shots scraped from match with id:7585
# Shots scraped from match with id:7586
# Shots scraped from match with id:8656
# Shots scraped from match with id:8651
# Shots scraped from match with id:7567
# Shots scraped from match with id:7541
# Shots scraped from match with id:8655
# Shots scraped from match with id:8657
# Shots scraped from match with id:7540
# Shots scraped from match with id:8652
# Shots scraped from match with id:7563
# Shots scraped from match with id:7556
# Shots scraped from match with id:7559
# Shots scraped from match with id:3827767
# Shots scraped from match with id:3827335
# Shots scraped from match with id:3827336
# Shots scraped from match with id:3827338
# Shots scraped from match with id:3827337
# Shots scraped from match with id:3817856
# Shots scraped from match with id:3817891
# Shots scraped from match with id:3817870
# Shots scraped from match with id:3817899
# Shots scraped from match with id:3817866
# Shots scraped from match with id:3817889
# Shots scraped from match with id:3817887
# Shots scraped from match with id:3817872
# Shots scraped from match with id:3817900
# Shots scraped from match with id:3817855
# Shots scraped from match with id:3817863
# Shots scraped from match with id:3817877
# Shots scraped from match with id:3817901
# Shots scraped from match with id:3817880
# Shots scraped from match with id:3817902
# Shots scraped from match with id:3817862
# Shots scraped from match with id:3817873
# Shots scraped from match with id:3817869
# Shots scraped from match with id:3817881
# Shots scraped from match with id:3817895
# Shots scraped from match with id:3817884
# Shots scraped from match with id:3817896
# Shots scraped from match with id:3817852
# Shots scraped from match with id:3817883
# Shots scraped from match with id:3817886
# Shots scraped from match with id:3817864
# Shots scraped from match with id:3817882
# Shots scraped from match with id:3817894
# Shots scraped from match with id:3817871
# Shots scraped from match with id:3817861
# Shots scraped from match with id:3817888
# Shots scraped from match with id:3817875
# Shots scraped from match with id:3817868
# Shots scraped from match with id:3817867
# Shots scraped from match with id:3813313
# Shots scraped from match with id:3817890
# Shots scraped from match with id:3813302
# Shots scraped from match with id:3817857
# Shots scraped from match with id:3817898
# Shots scraped from match with id:3817893
# Shots scraped from match with id:3817854
# Shots scraped from match with id:3817892
# Shots scraped from match with id:3817859
# Shots scraped from match with id:3817858
# Shots scraped from match with id:3817897
# Shots scraped from match with id:3817885
# Shots scraped from match with id:3817878
# Shots scraped from match with id:3817876
# Shots scraped from match with id:3813305
# Shots scraped from match with id:3813266
# Shots scraped from match with id:3813271
# Shots scraped from match with id:3813311
# Shots scraped from match with id:3813303
# Shots scraped from match with id:3813304
# Shots scraped from match with id:3813306
# Shots scraped from match with id:3813283
# Shots scraped from match with id:3813275
# Shots scraped from match with id:3813278
# Shots scraped from match with id:3813295
# Shots scraped from match with id:3813296
# Shots scraped from match with id:3813282
# Shots scraped from match with id:3813269
# Shots scraped from match with id:3817879
# Shots scraped from match with id:3817874
# Shots scraped from match with id:3817865
# Shots scraped from match with id:3817860
# Shots scraped from match with id:3817853
# Shots scraped from match with id:3817851
# Shots scraped from match with id:3817850
# Shots scraped from match with id:3817849
# Shots scraped from match with id:3817848
# Shots scraped from match with id:3813318
# Shots scraped from match with id:3813287
# Shots scraped from match with id:3813270
# Shots scraped from match with id:3813307
# Shots scraped from match with id:3813279
# Shots scraped from match with id:3813281
# Shots scraped from match with id:3813274
# Shots scraped from match with id:3813285
# Shots scraped from match with id:3813317
# Shots scraped from match with id:3813316
# Shots scraped from match with id:3813315
# Shots scraped from match with id:3813314
# Shots scraped from match with id:3813312
# Shots scraped from match with id:3813310
# Shots scraped from match with id:3813309
# Shots scraped from match with id:3813308
# Shots scraped from match with id:3813301
# Shots scraped from match with id:3813300
# Shots scraped from match with id:3813299
# Shots scraped from match with id:3813298
# Shots scraped from match with id:3813297
# Shots scraped from match with id:3813294
# Shots scraped from match with id:3813293
# Shots scraped from match with id:3813292
# Shots scraped from match with id:3813291
# Shots scraped from match with id:3813290
# Shots scraped from match with id:3813289
# Shots scraped from match with id:3813288
# Shots scraped from match with id:3813286
# Shots scraped from match with id:3813284
# Shots scraped from match with id:3813280
# Shots scraped from match with id:3813277
# Shots scraped from match with id:3813276
# Shots scraped from match with id:3813273
# Shots scraped from match with id:3813272
# Shots scraped from match with id:3813268
# Shots scraped from match with id:3813267
# Shots scraped from match with id:3813265
# Shots scraped from match with id:3813264
# Shots scraped from match with id:3773457
# Shots scraped from match with id:3773631
# Shots scraped from match with id:3773665
# Shots scraped from match with id:3773497
# Shots scraped from match with id:3773660
# Shots scraped from match with id:3773593
# Shots scraped from match with id:3773466
# Shots scraped from match with id:3773585
# Shots scraped from match with id:3773552
# Shots scraped from match with id:3773672
# Shots scraped from match with id:3773386
# Shots scraped from match with id:3773565
# Shots scraped from match with id:3773587
# Shots scraped from match with id:3773656
# Shots scraped from match with id:3773377
# Shots scraped from match with id:3773586
# Shots scraped from match with id:3773372
# Shots scraped from match with id:3773387
# Shots scraped from match with id:3773695
# Shots scraped from match with id:3773369
# Shots scraped from match with id:3773661
# Shots scraped from match with id:3773597
# Shots scraped from match with id:3773523
# Shots scraped from match with id:3773571
# Shots scraped from match with id:3773428
# Shots scraped from match with id:3764661
# Shots scraped from match with id:3773526
# Shots scraped from match with id:3773474
# Shots scraped from match with id:3773625
# Shots scraped from match with id:3773403
# Shots scraped from match with id:3773547
# Shots scraped from match with id:3773415
# Shots scraped from match with id:3764440
# Shots scraped from match with id:3773689
# Shots scraped from match with id:3773477
# Shots scraped from match with id:303731
# Shots scraped from match with id:303532
# Shots scraped from match with id:303516
# Shots scraped from match with id:303596
# Shots scraped from match with id:303430
# Shots scraped from match with id:303725
# Shots scraped from match with id:303504
# Shots scraped from match with id:303451
# Shots scraped from match with id:303664
# Shots scraped from match with id:303682
# Shots scraped from match with id:303400
# Shots scraped from match with id:303634
# Shots scraped from match with id:303421
# Shots scraped from match with id:303493
# Shots scraped from match with id:303680
# Shots scraped from match with id:303479
# Shots scraped from match with id:303615
# Shots scraped from match with id:303696
# Shots scraped from match with id:303487
# Shots scraped from match with id:303600
# Shots scraped from match with id:303548
# Shots scraped from match with id:303652
# Shots scraped from match with id:303674
# Shots scraped from match with id:303470
# Shots scraped from match with id:303700
# Shots scraped from match with id:303707
# Shots scraped from match with id:303666
# Shots scraped from match with id:303715
# Shots scraped from match with id:303377
# Shots scraped from match with id:303524
# Shots scraped from match with id:303517
# Shots scraped from match with id:303610
# Shots scraped from match with id:303473
# Shots scraped from match with id:15978
# Shots scraped from match with id:15998
# Shots scraped from match with id:16029
# Shots scraped from match with id:16073
# Shots scraped from match with id:16086
# Shots scraped from match with id:16190
# Shots scraped from match with id:16109
# Shots scraped from match with id:16120
# Shots scraped from match with id:16182
# Shots scraped from match with id:16215
# Shots scraped from match with id:16173
# Shots scraped from match with id:16265
# Shots scraped from match with id:15946
# Shots scraped from match with id:16157
# Shots scraped from match with id:16136
# Shots scraped from match with id:16248
# Shots scraped from match with id:16056
# Shots scraped from match with id:16289
# Shots scraped from match with id:16079
# Shots scraped from match with id:16149
# Shots scraped from match with id:16275
# Shots scraped from match with id:15973
# Shots scraped from match with id:16317
# Shots scraped from match with id:16131
# Shots scraped from match with id:16205
# Shots scraped from match with id:16095
# Shots scraped from match with id:16306
# Shots scraped from match with id:16010
# Shots scraped from match with id:15986
# Shots scraped from match with id:16240
# Shots scraped from match with id:16023
# Shots scraped from match with id:16196
# Shots scraped from match with id:15956
# Shots scraped from match with id:16231
# Shots scraped from match with id:9912
# Shots scraped from match with id:9880
# Shots scraped from match with id:9924
# Shots scraped from match with id:9855
# Shots scraped from match with id:9827
# Shots scraped from match with id:9799
# Shots scraped from match with id:9636
# Shots scraped from match with id:9609
# Shots scraped from match with id:9575
# Shots scraped from match with id:9928
# Shots scraped from match with id:9736
# Shots scraped from match with id:9742
# Shots scraped from match with id:9765
# Shots scraped from match with id:9661
# Shots scraped from match with id:9592
# Shots scraped from match with id:9870
# Shots scraped from match with id:9783
# Shots scraped from match with id:9700
# Shots scraped from match with id:9860
# Shots scraped from match with id:9695
# Shots scraped from match with id:9794
# Shots scraped from match with id:9717
# Shots scraped from match with id:9673
# Shots scraped from match with id:9650
# Shots scraped from match with id:9620
# Shots scraped from match with id:9837
# Shots scraped from match with id:9811
# Shots scraped from match with id:9642
# Shots scraped from match with id:9774
# Shots scraped from match with id:9602
# Shots scraped from match with id:9948
# Shots scraped from match with id:9682
# Shots scraped from match with id:9581
# Shots scraped from match with id:9726
# Shots scraped from match with id:9754
# Shots scraped from match with id:9889
# Shots scraped from match with id:266989
# Shots scraped from match with id:266357
# Shots scraped from match with id:267569
# Shots scraped from match with id:267212
# Shots scraped from match with id:266669
# Shots scraped from match with id:266892
# Shots scraped from match with id:267220
# Shots scraped from match with id:267670
# Shots scraped from match with id:266516
# Shots scraped from match with id:267039
# Shots scraped from match with id:266477
# Shots scraped from match with id:267101
# Shots scraped from match with id:266440
# Shots scraped from match with id:266033
# Shots scraped from match with id:267660
# Shots scraped from match with id:266273
# Shots scraped from match with id:267395
# Shots scraped from match with id:266874
# Shots scraped from match with id:266731
# Shots scraped from match with id:266528
# Shots scraped from match with id:266280
# Shots scraped from match with id:267432
# Shots scraped from match with id:267076
# Shots scraped from match with id:267590
# Shots scraped from match with id:267373
# Shots scraped from match with id:267077
# Shots scraped from match with id:266952
# Shots scraped from match with id:267464
# Shots scraped from match with id:266299
# Shots scraped from match with id:266191
# Shots scraped from match with id:265952
# Shots scraped from match with id:267492
# Shots scraped from match with id:267596
# Shots scraped from match with id:267058
# Shots scraped from match with id:266498
# Shots scraped from match with id:266986
# Shots scraped from match with id:267533
# Shots scraped from match with id:266310
# Shots scraped from match with id:267576
# Shots scraped from match with id:266653
# Shots scraped from match with id:265944
# Shots scraped from match with id:265894
# Shots scraped from match with id:265958
# Shots scraped from match with id:267611
# Shots scraped from match with id:267422
# Shots scraped from match with id:266236
# Shots scraped from match with id:267274
# Shots scraped from match with id:266961
# Shots scraped from match with id:266885
# Shots scraped from match with id:266815
# Shots scraped from match with id:267506
# Shots scraped from match with id:266664
# Shots scraped from match with id:266106
# Shots scraped from match with id:266670
# Shots scraped from match with id:266149
# Shots scraped from match with id:266620
# Shots scraped from match with id:266056
# Shots scraped from match with id:267327
# Shots scraped from match with id:266166
# Shots scraped from match with id:266160
# Shots scraped from match with id:265839
# Shots scraped from match with id:266424
# Shots scraped from match with id:266467
# Shots scraped from match with id:267273
# Shots scraped from match with id:266490
# Shots scraped from match with id:266254
# Shots scraped from match with id:266557
# Shots scraped from match with id:267183
# Shots scraped from match with id:265835
# Shots scraped from match with id:266838
# Shots scraped from match with id:265963
# Shots scraped from match with id:266117
# Shots scraped from match with id:266916
# Shots scraped from match with id:267197
# Shots scraped from match with id:70264
# Shots scraped from match with id:70273
# Shots scraped from match with id:267301
# Shots scraped from match with id:265896
# Shots scraped from match with id:265866
# Shots scraped from match with id:267400
# Shots scraped from match with id:266406
# Shots scraped from match with id:267085
# Shots scraped from match with id:267561
# Shots scraped from match with id:266148
# Shots scraped from match with id:266045
# Shots scraped from match with id:70303
# Shots scraped from match with id:266240
# Shots scraped from match with id:267597
# Shots scraped from match with id:266794
# Shots scraped from match with id:267343
# Shots scraped from match with id:266631
# Shots scraped from match with id:266320
# Shots scraped from match with id:266230
# Shots scraped from match with id:266525
# Shots scraped from match with id:266560
# Shots scraped from match with id:266846
# Shots scraped from match with id:266531
# Shots scraped from match with id:266921
# Shots scraped from match with id:267499
# Shots scraped from match with id:266741
# Shots scraped from match with id:266871
# Shots scraped from match with id:266967
# Shots scraped from match with id:266929
# Shots scraped from match with id:266770
# Shots scraped from match with id:266142
# Shots scraped from match with id:267368
# Shots scraped from match with id:70301
# Shots scraped from match with id:70298
# Shots scraped from match with id:70302
# Shots scraped from match with id:70291
# Shots scraped from match with id:267138
# Shots scraped from match with id:267520
# Shots scraped from match with id:70289
# Shots scraped from match with id:266066
# Shots scraped from match with id:267675
# Shots scraped from match with id:70288
# Shots scraped from match with id:266074
# Shots scraped from match with id:267567
# Shots scraped from match with id:266201
# Shots scraped from match with id:266274
# Shots scraped from match with id:70293
# Shots scraped from match with id:265918
# Shots scraped from match with id:70277
# Shots scraped from match with id:70283
# Shots scraped from match with id:70306
# Shots scraped from match with id:266256
# Shots scraped from match with id:266613
# Shots scraped from match with id:266491
# Shots scraped from match with id:265830
# Shots scraped from match with id:265857
# Shots scraped from match with id:266883
# Shots scraped from match with id:266603
# Shots scraped from match with id:265837
# Shots scraped from match with id:266462
# Shots scraped from match with id:267192
# Shots scraped from match with id:266420
# Shots scraped from match with id:266015
# Shots scraped from match with id:70270
# Shots scraped from match with id:70281
# Shots scraped from match with id:70308
# Shots scraped from match with id:70282
# Shots scraped from match with id:266724
# Shots scraped from match with id:70272
# Shots scraped from match with id:70304
# Shots scraped from match with id:70280
# Shots scraped from match with id:70296
# Shots scraped from match with id:70297
# Shots scraped from match with id:266433
# Shots scraped from match with id:70256
# Shots scraped from match with id:70259
# Shots scraped from match with id:70260
# Shots scraped from match with id:70263
# Shots scraped from match with id:70276
# Shots scraped from match with id:70287
# Shots scraped from match with id:70284
# Shots scraped from match with id:70275
# Shots scraped from match with id:70286
# Shots scraped from match with id:70309
# Shots scraped from match with id:70300
# Shots scraped from match with id:70295
# Shots scraped from match with id:70307
# Shots scraped from match with id:70305
# Shots scraped from match with id:266827
# Shots scraped from match with id:267502
# Shots scraped from match with id:70271
# Shots scraped from match with id:70294
# Shots scraped from match with id:70262
# Shots scraped from match with id:70292
# Shots scraped from match with id:69328
# Shots scraped from match with id:69329
# Shots scraped from match with id:70219
# Shots scraped from match with id:69331
# Shots scraped from match with id:69337
# Shots scraped from match with id:69322
# Shots scraped from match with id:69316
# Shots scraped from match with id:69332
# Shots scraped from match with id:69335
# Shots scraped from match with id:69330
# Shots scraped from match with id:69297
# Shots scraped from match with id:69325
# Shots scraped from match with id:69324
# Shots scraped from match with id:70225
# Shots scraped from match with id:69293
# Shots scraped from match with id:70223
# Shots scraped from match with id:69333
# Shots scraped from match with id:69264
# Shots scraped from match with id:69343
# Shots scraped from match with id:69340
# Shots scraped from match with id:69265
# Shots scraped from match with id:69319
# Shots scraped from match with id:69334
# Shots scraped from match with id:69327
# Shots scraped from match with id:69315
# Shots scraped from match with id:69336
# Shots scraped from match with id:69326
# Shots scraped from match with id:69268
# Shots scraped from match with id:69320
# Shots scraped from match with id:69312
# Shots scraped from match with id:69314
# Shots scraped from match with id:69318
# Shots scraped from match with id:69338
# Shots scraped from match with id:70220
# Shots scraped from match with id:70224
# Shots scraped from match with id:70221
# Shots scraped from match with id:69323
# Shots scraped from match with id:69276
# Shots scraped from match with id:69304
# Shots scraped from match with id:69307
# Shots scraped from match with id:69271
# Shots scraped from match with id:69305
# Shots scraped from match with id:69278
# Shots scraped from match with id:69275
# Shots scraped from match with id:69295
# Shots scraped from match with id:69270
# Shots scraped from match with id:69303
# Shots scraped from match with id:69245
# Shots scraped from match with id:69287
# Shots scraped from match with id:69296
# Shots scraped from match with id:69260
# Shots scraped from match with id:69269
# Shots scraped from match with id:69246
# Shots scraped from match with id:69302
# Shots scraped from match with id:69282
# Shots scraped from match with id:69274
# Shots scraped from match with id:69283
# Shots scraped from match with id:69280
# Shots scraped from match with id:69286
# Shots scraped from match with id:69291
# Shots scraped from match with id:69236
# Shots scraped from match with id:69234
# Shots scraped from match with id:69272
# Shots scraped from match with id:69308
# Shots scraped from match with id:69299
# Shots scraped from match with id:69300
# Shots scraped from match with id:69289
# Shots scraped from match with id:69263
# Shots scraped from match with id:69306
# Shots scraped from match with id:69248
# Shots scraped from match with id:69243
# Shots scraped from match with id:69241
# Shots scraped from match with id:69239
# Shots scraped from match with id:69257
# Shots scraped from match with id:69253
# Shots scraped from match with id:69244
# Shots scraped from match with id:69277
# Shots scraped from match with id:69229
# Shots scraped from match with id:69219
# Shots scraped from match with id:69218
# Shots scraped from match with id:69250
# Shots scraped from match with id:69242
# Shots scraped from match with id:69256
# Shots scraped from match with id:69298
# Shots scraped from match with id:69259
# Shots scraped from match with id:69224
# Shots scraped from match with id:69210
# Shots scraped from match with id:69220
# Shots scraped from match with id:69237
# Shots scraped from match with id:69226
# Shots scraped from match with id:69252
# Shots scraped from match with id:69255
# Shots scraped from match with id:69214
# Shots scraped from match with id:69262
# Shots scraped from match with id:69240
# Shots scraped from match with id:69233
# Shots scraped from match with id:69213
# Shots scraped from match with id:69238
# Shots scraped from match with id:69267
# Shots scraped from match with id:69288
# Shots scraped from match with id:69254
# Shots scraped from match with id:69292
# Shots scraped from match with id:69227
# Shots scraped from match with id:69247
# Shots scraped from match with id:69221
# Shots scraped from match with id:69225
# Shots scraped from match with id:69212
# Shots scraped from match with id:69235
# Shots scraped from match with id:69232
# Shots scraped from match with id:69216
# Shots scraped from match with id:69209
# Shots scraped from match with id:69231
# Shots scraped from match with id:69217
# Shots scraped from match with id:69273
# Shots scraped from match with id:69222
# Shots scraped from match with id:69223
# Shots scraped from match with id:69195
# Shots scraped from match with id:69251
# Shots scraped from match with id:69185
# Shots scraped from match with id:69142
# Shots scraped from match with id:69139
# Shots scraped from match with id:69189
# Shots scraped from match with id:69171
# Shots scraped from match with id:69249
# Shots scraped from match with id:69215
# Shots scraped from match with id:69138
# Shots scraped from match with id:69147
# Shots scraped from match with id:69177
# Shots scraped from match with id:69207
# Shots scraped from match with id:69228
# Shots scraped from match with id:69183
# Shots scraped from match with id:69279
# Shots scraped from match with id:69285
# Shots scraped from match with id:69211
# Shots scraped from match with id:69230
# Shots scraped from match with id:69149
# Shots scraped from match with id:69151
# Shots scraped from match with id:69144
# Shots scraped from match with id:69169
# Shots scraped from match with id:68360
# Shots scraped from match with id:69186
# Shots scraped from match with id:69180
# Shots scraped from match with id:69143
# Shots scraped from match with id:69181
# Shots scraped from match with id:68365
# Shots scraped from match with id:69178
# Shots scraped from match with id:68364
# Shots scraped from match with id:69170
# Shots scraped from match with id:68359
# Shots scraped from match with id:68356
# Shots scraped from match with id:69158
# Shots scraped from match with id:69187
# Shots scraped from match with id:68363
# Shots scraped from match with id:69166
# Shots scraped from match with id:68366
# Shots scraped from match with id:69148
# Shots scraped from match with id:69184
# Shots scraped from match with id:69173
# Shots scraped from match with id:69146
# Shots scraped from match with id:69182
# Shots scraped from match with id:68358
# Shots scraped from match with id:68361
# Shots scraped from match with id:69141
# Shots scraped from match with id:69145
# Shots scraped from match with id:69176
# Shots scraped from match with id:69179
# Shots scraped from match with id:68334
# Shots scraped from match with id:68333
# Shots scraped from match with id:68336
# Shots scraped from match with id:68326
# Shots scraped from match with id:69162
# Shots scraped from match with id:68335
# Shots scraped from match with id:68332
# Shots scraped from match with id:68330
# Shots scraped from match with id:68329
# Shots scraped from match with id:68341
# Shots scraped from match with id:69165
# Shots scraped from match with id:69155
# Shots scraped from match with id:69154
# Shots scraped from match with id:69156
# Shots scraped from match with id:69159
# Shots scraped from match with id:69175
# Shots scraped from match with id:69160
# Shots scraped from match with id:68331
# Shots scraped from match with id:68328
# Shots scraped from match with id:68340
# Shots scraped from match with id:69174
# Shots scraped from match with id:68347
# Shots scraped from match with id:68327
# Shots scraped from match with id:69157
# Shots scraped from match with id:69164
# Shots scraped from match with id:68324
# Shots scraped from match with id:68320
# Shots scraped from match with id:68323
# Shots scraped from match with id:69172
# Shots scraped from match with id:68339
# Shots scraped from match with id:68348
# Shots scraped from match with id:68354
# Shots scraped from match with id:68351
# Shots scraped from match with id:68317
# Shots scraped from match with id:68350
# Shots scraped from match with id:68325
# Shots scraped from match with id:68321
# Shots scraped from match with id:68319
# Shots scraped from match with id:68342
# Shots scraped from match with id:68322
# Shots scraped from match with id:68318
# Shots scraped from match with id:68314
# Shots scraped from match with id:68313
# Shots scraped from match with id:68316
# Shots scraped from match with id:68315
# Shots scraped from match with id:69153
# Shots scraped from match with id:68352
# Shots scraped from match with id:68353
# Shots scraped from match with id:7494
# Shots scraped from match with id:7486
# Shots scraped from match with id:7497
# Shots scraped from match with id:7430
# Shots scraped from match with id:7444
# Shots scraped from match with id:7443
# Shots scraped from match with id:7521
# Shots scraped from match with id:7492
# Shots scraped from match with id:7524
# Shots scraped from match with id:7496
# Shots scraped from match with id:7523
# Shots scraped from match with id:7520
# Shots scraped from match with id:7493
# Shots scraped from match with id:7500
# Shots scraped from match with id:7519
# Shots scraped from match with id:7473
# Shots scraped from match with id:7522
# Shots scraped from match with id:7484
# Shots scraped from match with id:7475
# Shots scraped from match with id:7457
# Shots scraped from match with id:7445
# Shots scraped from match with id:7490
# Shots scraped from match with id:7482
# Shots scraped from match with id:7479
# Shots scraped from match with id:7478
# Shots scraped from match with id:7456
# Shots scraped from match with id:7471
# Shots scraped from match with id:7477
# Shots scraped from match with id:7472
# Shots scraped from match with id:7474
# Shots scraped from match with id:7487
# Shots scraped from match with id:7485
# Shots scraped from match with id:7483
# Shots scraped from match with id:7476
# Shots scraped from match with id:7451
# Shots scraped from match with id:7480
# Shots scraped from match with id:3749052
# Shots scraped from match with id:3749522
# Shots scraped from match with id:3749246
# Shots scraped from match with id:3749257
# Shots scraped from match with id:3749642
# Shots scraped from match with id:3749358
# Shots scraped from match with id:3749346
# Shots scraped from match with id:3749253
# Shots scraped from match with id:3749079
# Shots scraped from match with id:3749465
# Shots scraped from match with id:3749133
# Shots scraped from match with id:3749528
# Shots scraped from match with id:3749233
# Shots scraped from match with id:3749462
# Shots scraped from match with id:3749552
# Shots scraped from match with id:3749296
# Shots scraped from match with id:3749454
# Shots scraped from match with id:3749276
# Shots scraped from match with id:3749068
# Shots scraped from match with id:3749310
# Shots scraped from match with id:3749493
# Shots scraped from match with id:3749434
# Shots scraped from match with id:3749192
# Shots scraped from match with id:3749196
# Shots scraped from match with id:3749448
# Shots scraped from match with id:3749360
# Shots scraped from match with id:3749453
# Shots scraped from match with id:3749278
# Shots scraped from match with id:3749603
# Shots scraped from match with id:3749108
# Shots scraped from match with id:3749153
# Shots scraped from match with id:3749403
# Shots scraped from match with id:3749526
# Shots scraped from match with id:3749431
# Shots scraped from match with id:3788769
# Shots scraped from match with id:3788766
# Shots scraped from match with id:3795220
# Shots scraped from match with id:3788761
# Shots scraped from match with id:3788764
# Shots scraped from match with id:3788773
# Shots scraped from match with id:3788755
# Shots scraped from match with id:3788754
# Shots scraped from match with id:3788762
# Shots scraped from match with id:3788760
# Shots scraped from match with id:3788747
# Shots scraped from match with id:3788741
# Shots scraped from match with id:3795109
# Shots scraped from match with id:3795187
# Shots scraped from match with id:3795108
# Shots scraped from match with id:3788770
# Shots scraped from match with id:3795506
# Shots scraped from match with id:3794688
# Shots scraped from match with id:3794692
# Shots scraped from match with id:3794686
# Shots scraped from match with id:3794687
# Shots scraped from match with id:3794685
# Shots scraped from match with id:3788774
# Shots scraped from match with id:3788771
# Shots scraped from match with id:3788772
# Shots scraped from match with id:3788768
# Shots scraped from match with id:3788767
# Shots scraped from match with id:3788753
# Shots scraped from match with id:3788765
# Shots scraped from match with id:3788763
# Shots scraped from match with id:3788759
# Shots scraped from match with id:3788758
# Shots scraped from match with id:3788757
# Shots scraped from match with id:3788745
# Shots scraped from match with id:3795107
# Shots scraped from match with id:3795221
# Shots scraped from match with id:3794689
# Shots scraped from match with id:3788746
# Shots scraped from match with id:3794691
# Shots scraped from match with id:3794690
# Shots scraped from match with id:3788756
# Shots scraped from match with id:3788749
# Shots scraped from match with id:3788750
# Shots scraped from match with id:3788748
# Shots scraped from match with id:3788751
# Shots scraped from match with id:3788752
# Shots scraped from match with id:3788742
# Shots scraped from match with id:3788775
# Shots scraped from match with id:3788776
# Shots scraped from match with id:3788743
# Shots scraped from match with id:3788744
# Shots scraped from match with id:3847567
# Shots scraped from match with id:3845506
# Shots scraped from match with id:3835335
# Shots scraped from match with id:3835323
# Shots scraped from match with id:3835325
# Shots scraped from match with id:3835324
# Shots scraped from match with id:3835331
# Shots scraped from match with id:3835320
# Shots scraped from match with id:3845507
# Shots scraped from match with id:3844387
# Shots scraped from match with id:3844384
# Shots scraped from match with id:3844385
# Shots scraped from match with id:3844386
# Shots scraped from match with id:3835342
# Shots scraped from match with id:3835337
# Shots scraped from match with id:3835338
# Shots scraped from match with id:3835330
# Shots scraped from match with id:3835329
# Shots scraped from match with id:3835322
# Shots scraped from match with id:3835332
# Shots scraped from match with id:3835327
# Shots scraped from match with id:3835326
# Shots scraped from match with id:3835341
# Shots scraped from match with id:3835340
# Shots scraped from match with id:3835339
# Shots scraped from match with id:3835336
# Shots scraped from match with id:3835334
# Shots scraped from match with id:3835328
# Shots scraped from match with id:3835333
# Shots scraped from match with id:3835321
# Shots scraped from match with id:3835319
# Shots scraped from match with id:22963
# Shots scraped from match with id:68311
# Shots scraped from match with id:68357
# Shots scraped from match with id:22933
# Shots scraped from match with id:22940
# Shots scraped from match with id:22943
# Shots scraped from match with id:22944
# Shots scraped from match with id:22945
# Shots scraped from match with id:22949
# Shots scraped from match with id:22956
# Shots scraped from match with id:22961
# Shots scraped from match with id:22964
# Shots scraped from match with id:22966
# Shots scraped from match with id:68344
# Shots scraped from match with id:68345
# Shots scraped from match with id:69163
# Shots scraped from match with id:68346
# Shots scraped from match with id:68355
# Shots scraped from match with id:69301
# Shots scraped from match with id:69137
# Shots scraped from match with id:69208
# Shots scraped from match with id:22936
# Shots scraped from match with id:22973
# Shots scraped from match with id:68337
# Shots scraped from match with id:22981
# Shots scraped from match with id:22974
# Shots scraped from match with id:22924
# Shots scraped from match with id:69321
# Shots scraped from match with id:22983
# Shots scraped from match with id:68312
# Shots scraped from match with id:22921
# Shots scraped from match with id:22926
# Shots scraped from match with id:22930
# Shots scraped from match with id:22934
# Shots scraped from match with id:22939
# Shots scraped from match with id:69202
# Shots scraped from match with id:22942
# Shots scraped from match with id:22948
# Shots scraped from match with id:22955
# Shots scraped from match with id:22962
# Shots scraped from match with id:22980
# Shots scraped from match with id:22984
# Shots scraped from match with id:68338
# Shots scraped from match with id:68343
# Shots scraped from match with id:68362
# Shots scraped from match with id:69191
# Shots scraped from match with id:69188
# Shots scraped from match with id:69199
# Shots scraped from match with id:69258
# Shots scraped from match with id:69284
# Shots scraped from match with id:69205
# Shots scraped from match with id:69161

# %% [markdown]
# ___
#
# <a id='section4'></a>
#
# ## <a id='#section4'>4. Extraction outcome</a>
# As a result of the extraction process, we now have a dataframe full of shots retrieved from various international and non-international competitions of both male and female players.

# %%
all_events.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  8975991a-ecaa-47ef-8b98-86e09c242131    183       1  00:04:56.223       4
# 1  fead457a-c1a7-42f4-84a6-ab7698e9df5e    750       1  00:16:43.605      16
# 2  e616c23c-786b-487b-a35d-af91f8d575ee    858       1  00:21:03.108      21
# 3  47cd9da1-eb07-4544-aca9-9fb5f2956055    899       1  00:21:54.174      21
# 4  c176824b-e608-4b52-98c4-f328748925b7   1108       1  00:29:38.907      29
#
#    second  type  possession possession_team    play_pattern  ...  \
# 0      56  Shot          12     Switzerland    Regular Play  ...
# 1      43  Shot          33        Portugal   From Throw In  ...
# 2       3  Shot          38        Portugal  From Free Kick  ...
# 3      54  Shot          42        Portugal    Regular Play  ...
# 4      38  Shot          57     Switzerland  From Free Kick  ...
#
#   shot_open_goal  out shot_one_on_one shot_saved_to_post  shot_deflected  \
# 0            NaN  NaN             NaN                NaN             NaN
# 1            NaN  NaN             NaN                NaN             NaN
# 2            NaN  NaN             NaN                NaN             NaN
# 3            NaN  NaN             NaN                NaN             NaN
# 4            NaN  NaN             NaN                NaN             NaN
#
#   shot_follows_dribble  shot_saved_off_target  shot_redirect off_camera  \
# 0                  NaN                    NaN            NaN        NaN
# 1                  NaN                    NaN            NaN        NaN
# 2                  NaN                    NaN            NaN        NaN
# 3                  NaN                    NaN            NaN        NaN
# 4                  NaN                    NaN            NaN        NaN
#
#   shot_kick_off
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 40 columns]

# %%
all_events.shape
# Out:
# (33266, 40)

# %%
# Saving our shots dataframe as parquet file
all_events.to_parquet('output//shots.parquet')
